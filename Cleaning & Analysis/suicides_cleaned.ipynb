# %%
import pandas as pd
import numpy as np
suicides_data = pd.read_csv("/Users/greshashah126/Desktop/master.csv", low_memory=False)
pd.set_option("display.max_columns", None)
suicides_data
# Out:
#                         country  year     sex          age  suicides_no  \
# 0                       Albania  1987    male  15-24 years         21.0
# 1                       Albania  1987    male  35-54 years         16.0
# 2                       Albania  1987  female  15-24 years         14.0
# 3                       Albania  1987    male    75+ years          1.0
# 4                       Albania  1987    male  25-34 years          9.0
# ...                         ...   ...     ...          ...          ...
# 31751                   Ukraine  2017  female    75+ years        256.0
# 31752            United Kingdom  2017  female    75+ years        104.0
# 31753  United States of America  2017  female    75+ years        501.0
# 31754                   Uruguay  2017  female    75+ years         14.0
# 31755                Uzbekistan  2017  female    75+ years          3.0
#
#        population  suicides/100k pop                  country-year  \
# ...

# %%
suicides_data.isnull().sum()
# Out:
# country                   0
# year                      0
# sex                       0
# age                       0
# suicides_no            1200
# population                0
# suicides/100k pop         0
# country-year              0
# HDI for year          19456
#  gdp_for_year ($)         0
# gdp_per_capita ($)        0
# generation                0
# dtype: int64

# %%
suicides_data['suicides_no'] = suicides_data['suicides_no'].fillna(0) 
suicides_data['HDI for year'] = suicides_data['HDI for year'].fillna(0)

# %%
suicides_data = suicides_data.drop(columns='country-year')

# %%
# Convert to integers
suicides_data['suicides_no'] = suicides_data['suicides_no'].astype(int)

# %%
suicides_data['suicides_no'].dtype
# Out:
# dtype('int64')

# %%
suicides_data.columns
# Out:
# Index(['country', 'year', 'sex', 'age', 'suicides_no', 'population',
#        'suicides/100k pop', 'HDI for year', ' gdp_for_year ($) ',
#        'gdp_per_capita ($)', 'generation'],
#       dtype='object')

# %%
suicides_data = suicides_data.rename(columns={' gdp_for_year ($) ': 'gdp_for_year($)'})

# %%
suicides_data['gdp_for_year($)'].unique()
# Out:
# array(['2,15,66,24,900', '2,12,60,00,000', '2,33,51,24,988', ...,
#        '1.95E+13', '64233966861', '62081323299'], dtype=object)

# %%
# Function to remove 'E+' part from numbers
def remove_num(x):
    if "E+" in x:
        return 0
    else:
        return x

suicides_data['gdp_for_year($)'] =  suicides_data['gdp_for_year($)'].apply(remove_num)
suicides_data['gdp_for_year($)'] = suicides_data['gdp_for_year($)'].str.replace(',', '')
suicides_data
# Out:
#                         country  year     sex          age  suicides_no  \
# 0                       Albania  1987    male  15-24 years           21
# 1                       Albania  1987    male  35-54 years           16
# 2                       Albania  1987  female  15-24 years           14
# 3                       Albania  1987    male    75+ years            1
# 4                       Albania  1987    male  25-34 years            9
# ...                         ...   ...     ...          ...          ...
# 31751                   Ukraine  2017  female    75+ years          256
# 31752            United Kingdom  2017  female    75+ years          104
# 31753  United States of America  2017  female    75+ years          501
# 31754                   Uruguay  2017  female    75+ years           14
# 31755                Uzbekistan  2017  female    75+ years            3
#
#        population  suicides/100k pop  HDI for year gdp_for_year($)  \
# ...

# %%
suicides_data.isnull().sum()
# Out:
# country                  0
# year                     0
# sex                      0
# age                      0
# suicides_no              0
# population               0
# suicides/100k pop        0
# HDI for year             0
# gdp_for_year($)       2172
# gdp_per_capita ($)       0
# generation               0
# dtype: int64

# %%
suicides_data['gdp_for_year($)'] = suicides_data['gdp_for_year($)'].fillna(0) 
suicides_data
# Out:
#                         country  year     sex          age  suicides_no  \
# 0                       Albania  1987    male  15-24 years           21
# 1                       Albania  1987    male  35-54 years           16
# 2                       Albania  1987  female  15-24 years           14
# 3                       Albania  1987    male    75+ years            1
# 4                       Albania  1987    male  25-34 years            9
# ...                         ...   ...     ...          ...          ...
# 31751                   Ukraine  2017  female    75+ years          256
# 31752            United Kingdom  2017  female    75+ years          104
# 31753  United States of America  2017  female    75+ years          501
# 31754                   Uruguay  2017  female    75+ years           14
# 31755                Uzbekistan  2017  female    75+ years            3
#
#        population  suicides/100k pop  HDI for year gdp_for_year($)  \
# ...

# %%
suicides_data['gdp_for_year($)'].dtype
# Out:
# dtype('O')

# %%
suicides_data['gdp_for_year($)'] = suicides_data['gdp_for_year($)'].astype(int)

# %%
suicides_data['gdp_per_capita ($)'].dtype
# Out:
# dtype('float64')

# %%
#Reducing decimal place 
suicides_data['gdp_per_capita ($)'] = suicides_data['gdp_per_capita ($)'].apply (lambda x: round(x, 2))
suicides_data['suicides/100k pop'] = suicides_data['suicides/100k pop'].apply (lambda x: round(x, 3))
suicides_data['HDI for year'] = suicides_data['HDI for year'].apply (lambda x: round(x, 3))
suicides_data
# Out:
#                         country  year     sex          age  suicides_no  \
# 0                       Albania  1987    male  15-24 years           21
# 1                       Albania  1987    male  35-54 years           16
# 2                       Albania  1987  female  15-24 years           14
# 3                       Albania  1987    male    75+ years            1
# 4                       Albania  1987    male  25-34 years            9
# ...                         ...   ...     ...          ...          ...
# 31751                   Ukraine  2017  female    75+ years          256
# 31752            United Kingdom  2017  female    75+ years          104
# 31753  United States of America  2017  female    75+ years          501
# 31754                   Uruguay  2017  female    75+ years           14
# 31755                Uzbekistan  2017  female    75+ years            3
#
#        population  suicides/100k pop  HDI for year  gdp_for_year($)  \
# ...

# %%
suicides_data.to_csv("SuicidesData_cleaned.csv", index=False)
